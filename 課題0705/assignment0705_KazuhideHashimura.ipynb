# %% [markdown]
# # 課題0705
#
# そのまま課題ファイルで編集しないでください。課題ファイルを複製してから課題を回答してください。

# %% [markdown]
# ## 課題1
#
# pandasでDataフォルダの```example.json```を読み込む。

# %%
import pandas as pd
import json

# %%
df = pd.read_csv("/Users/Kazuhide/chss_2023_assignment/課題0705/Data/example.json")
df

# %% [markdown]
# ## 課題2
#
# pandasでDataフォルダの```state-abbrevs.csv```、```state-areas.csv```、```state-population.csv```を読み込む。
#
# これらのデータを使って、**2010年**アメリカの各州の人口密度を計算しよう。

# %%
df2 = pd.read_csv("/Users/Kazuhide/chss_2023_assignment/課題0705/Data/state-abbrevs.csv")
df3 = pd.read_csv("/Users/Kazuhide/chss_2023_assignment/課題0705/Data/state-areas.csv")
df4 = pd.read_csv("/Users/Kazuhide/chss_2023_assignment/課題0705/Data/state-population.csv")

# %%
#データフレームの結合
##2010年&全年代で絞り込み
df5 = df4[(df4["year"] == 2010) & (df4["ages"] == "total")]
##df2とdf3の結合
df6 = pd.merge(df2,df3)
##df5をdf6と結合できる形に変更
df5_new = df5.rename(columns={'state/region': 'abbreviation'})
##全てを一つにまとめる
df7 = pd.merge(df5_new, df6, on='abbreviation')
display(df7)
# Out:
#    abbreviation   ages  year  population                 state  area (sq. mi)
# 0            AL  total  2010   4785570.0               Alabama          52423
# 1            AK  total  2010    713868.0                Alaska         656425
# 2            AZ  total  2010   6408790.0               Arizona         114006
# 3            AR  total  2010   2922280.0              Arkansas          53182
# 4            CA  total  2010  37333601.0            California         163707
# 5            CO  total  2010   5048196.0              Colorado         104100
# 6            CT  total  2010   3579210.0           Connecticut           5544
# 7            DE  total  2010    899711.0              Delaware           1954
# 8            DC  total  2010    605125.0  District of Columbia             68
# 9            FL  total  2010  18846054.0               Florida          65758
# 10           GA  total  2010   9713248.0               Georgia          59441
# ...

# %%
#2010年アメリカの各州の人口密度を計算
df8 = df7["population"] / df7["area (sq. mi)"]
df9 = pd.DataFrame(df8)
df9
# Out:
#               0
# 0     91.287603
# 1      1.087509
# 2     56.214497
# 3     54.948667
# 4    228.051342
# 5     48.493718
# 6    645.600649
# 7    460.445752
# 8   8898.897059
# 9    286.597129
# 10   163.409902
# 11   124.746707
# 12    18.794338
# 13   221.687472
# 14   178.197831
# 15    54.202751
# 16    34.745266
# 17   107.586994
# 18    87.676099
# 19    37.509990
# 20   466.445797
# 21   621.815538
# 22   102.015794
# 23    61.078373
# 24    61.321530
# 25    86.015622
# 26     6.736171
# 27    23.654153
# 28    24.448796
# 29   140.799273
# 30  1009.253268
# 31    16.982737
# 32   356.094135
# 33   177.617157
# 34     9.537565
# 35   257.549634
# 36    53.778278
# 37    39.001565
# 38   275.966651
# 39   681.339159
# 40   144.854594
# 41    10.583512
# 42   150.825298
# 43    93.987655
# 44    32.677188
# 45    65.085075
# 46   187.622273
# 47    94.557817
# 48    76.519582
# 49    86.851900
# 50     5.768079

# %% [markdown]
# ## 課題3
#
# ```state/region```、```ages```と```years```でデータフレームをグループして、各グループで$\frac{population}{area (sq. mi)}$の形で人口密度を計算してください。

# %%
#多対一結合
display(df4, df6, pd.merge(df4, df6))






##2010年&全年代で絞り込み
df5 = df4[(df4["year"] == 2010) & (df4["ages"] == "total")]
##df2とdf3の結合
df6 = pd.merge(df2,df3)
##df5をdf6と結合できる形に変更
df5_new = df5.rename(columns={'state/region': 'abbreviation'})
##全てを一つにまとめる
df7 = pd.merge(df5_new, df6, on='abbreviation')
display(df7)

# %%
#多対一結合
df4_new = df4.rename(columns={'state/region': 'abbreviation'})
display(df4_new, df6, pd.merge(df4_new,df6))
df10 = pd.merge(df4_new,df6)
# Out:
#      abbreviation     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]
#                    state abbreviation  area (sq. mi)
# 0                Alabama           AL          52423
# 1                 Alaska           AK         656425
# 2                Arizona           AZ         114006
# 3               Arkansas           AR          53182
# 4             California           CA         163707
# 5               Colorado           CO         104100
# ...

# %%
#state/regionとagesと`yearsでデータフレームをグループして、各グループでで人口密度を計算
##失敗
### df.groupby(["state","ages","year"])["population"].transform(lambda x: x/df10["area (sq. mi)"])

##◯
df10["population"]/df10["area (sq. mi)"]
# Out:
# 0       21.316769
# 1       91.897221
# 2       21.573851
# 3       91.287603
# 4       21.474601
#           ...
# 2443     1.405242
# 2444     4.695046
# 2445     1.397698
# 2446     1.391135
# 2447     4.638103
# Length: 2448, dtype: float64

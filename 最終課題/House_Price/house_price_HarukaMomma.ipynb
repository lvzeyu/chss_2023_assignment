# %% [markdown]
# # House Price Prediction
#
# ```Data/house_price.csv```には、住宅の価格(```SalePrice```)と住宅の関連情報が格納されています。
#
# - このデータを用いて、住宅の価格(```SalePrice```)を予測するモデルを構築、評価しなさい。
# - データ中身を確認しながら、適切な特徴量エンジニアリングやモデル選定ための考えもまとめてください。

# %%
import pandas as pd
import numpy as np
house=pd.read_csv("C:/Users/Harekaze/Desktop/chss_2023_assignment/最終課題/House_Price/Data/house_price.csv")
house
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# データの可視化

# %%
pip show proplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\harekaze\anaconda3\lib\site-packages)
# WARNING: Package(s) not found: proplot

# %%
pip install proplot
#proplotがインストールできませんでした
# Out:
#   Cell In[6], line 1
#     pip install proplot
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
x1 = house.LotFrontage
x2 = house.LotArea
y = house.SalePrice

fig, ax = plt.subplots()

ax.plot(x1, y )
#linestyle='solid', marker='o'

ax.set_xlabel(house.LotFrontage)
ax.set_ylabel(house.SalePrice)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 10
#       7 ax.plot(x1, y )
#       8 #linestyle='solid', marker='o'
# ---> 10 ax.set_xlabel(house.LotFrontage)
#      11 ax.set_ylabel(house.SalePrice)
#      13 plt.show()
#
# File c:\Users\Harekaze\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3472, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3465     x = {
#    3466         'left': 0,
#    3467         'center': 0.5,
#    3468         'right': 1,
#    3469     }[loc]
#    3470     kwargs.update(x=x, horizontalalignment=loc)
# -> 3472 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File c:\Users\Harekaze\anaconda3\lib\site-packages\matplotlib\axis.py:1789, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1776 """
#    1777 Set the text value of the axis label.
#    1778
#    (...)
# ...

# %%
x1 = house.LotFrontage
x2 = house.LotArea
y = house.SalePrice

plt.plot(x2,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 x2 = house.LotArea
#       3 y = house.SalePrice
# ----> 5 plt.plot(x2,y)
#
# NameError: name 'plt' is not defined

# %%
x3=house.MSSubClass
y=house.SalePrice

plt.plot(x3,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 x3=house.MSSubClass
#       2 y=house.SalePrice
# ----> 4 plt.plot(x3,y)
#
# NameError: name 'plt' is not defined

# %%
#モデル
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

house=pd.read_csv("C:/Users/Harekaze/Desktop/chss_2023_assignment/最終課題/House_Price/Data/house_price.csv")
X = house[:, 2:3]  # Petal length as input feature
y = house.SalePrice
 # Petal width as target variable


# 訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

model=LinearRegression() # 線形回帰モデル
model.fit(X_train,y_train) # モデルを訓練データに適合
y_predicted=model.predict(X_test) # テストデータで予測
mean_squared_error(y_test,y_predicted) # 予測精度（平均二乗誤差）の評価
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Harekaze\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Harekaze\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Harekaze\anaconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(2, 3, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 from sklearn.metrics import mean_squared_error
# ...

# %%
#モデル
from sklearn.linear_model import LinearRegression

#ハイパーパラメータ/とりあえずlogisticでやってみる
model=LogisticRegression(solver='lbfgs',  multi_class='auto')

# %%
#データの準備
from sklearn.model_selection import train_test_split
from sklearn import datasets

house=pd.read_csv("C:/Users/Harekaze/Desktop/chss_2023_assignment/最終課題/House_Price/Data/house_price.csv")
X = house.data # 特徴量データ
y = house.SalePrice # ラベルデータ

assert len(X) == len(y)

# 訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 6
#       3 from sklearn import datasets
#       5 house=pd.read_csv("C:/Users/Harekaze/Desktop/chss_2023_assignment/最終課題/House_Price/Data/house_price.csv")
# ----> 6 X = house.data # 特徴量データ
#       7 y = house.SalePrice # ラベルデータ
#       9 assert len(X) == len(y)
#
# File c:\Users\Harekaze\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
# モデルを訓練データに適合
model.fit(X_train, y_train)

# %%
# テストデータでラベルを予測
y_predicted=model.predict(X_test)

# %%
#予測精度の評価
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predicted)
